# %% [markdown]
# # Test Cluster DSR

# %%
#Importar Librerias
import pandas as pd 
import os
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime 
from IPython.display import Image
NOW = "09/03/2020"

# %%
mainpath = "D:/Empresas/DSR/Analitica_Micromovilidad/"
dataname = "test.csv"
dataoutput = "RFM_Segmento_1002_to_2802"

fullpathdata = os.path.join(mainpath,dataname)
fullpathoutput = os.path.join(mainpath,dataoutput)

# %%
print(fullpathdata)
print(fullpathoutput)
print(NOW)
# Out:
# D:/Empresas/DSR/Analitica_Micromovilidad/test.csv
# D:/Empresas/DSR/Analitica_Micromovilidad/RFM_Segmento_1002_to_2802
# 09/03/2020

# %% [markdown]
# # Funciones de Apoyo

# %%
def days_between(d1, d2):
  #  d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%d/%m/%Y")
    return abs((d2 - d1).days)

# %%
def format_date(d):
    return d[0:2] + "/"+ d[3:5] + "/2020"

# %%
def r_score(x,quintiles):
    if x <= quintiles['Recency'][.2]:
        return 5
    elif x <= quintiles['Recency'][.4]:
        return 4
    elif x <= quintiles['Recency'][.6]:
        return 3
    elif x <= quintiles['Recency'][.8]:
        return 2
    else:
        return 1
def fm_score(x, c,quintiles):
    if x <= quintiles[c][.2]:
        return 1
    elif x <= quintiles[c][.4]:
        return 2
    elif x <= quintiles[c][.6]:
        return 3
    elif x <= quintiles[c][.8]:
        return 4
    else:
        return 5

# %% [markdown]
# # Definir función para hallar el Score en base a los quintiles

# %%
def rfm_table_score(rfm_table,quintiles): 
    rfm_table['R'] = rfm_table['Recency'].apply(lambda x: r_score(x,quintiles))
    rfm_table['F'] = rfm_table['Frequency'].apply(lambda x: fm_score(x, 'Frequency',quintiles))
    rfm_table['M'] = rfm_table['Monetary'].apply(lambda x: fm_score(x, 'Monetary',quintiles))
    rfm_table['RFM Score'] = rfm_table['R'].map(str) + rfm_table['F'].map(str) + rfm_table['M'].map(str)
    return rfm_table

# %%
def rfm_table_segment(rfm_table,segt_map,segt_other):
    rfm_table['Segment'] = rfm_table['RFM Score']
    rfm_table['Segment'] = rfm_table['Segment'].replace(segt_map, regex=True)
    rfm_table['Segment'] = rfm_table['Segment'].replace(segt_other, regex=True)
    return rfm_table

# %%
Image(filename=mainpath+'rfm-segments.png')

# %%
Image(filename=mainpath+'RFM_Rules.jpg',width=400,height=60)

# %%
segt_map = {
    r'[4-5][4-5][4-5]': 'A. Champions',
    r'[2-5][3-5][3-5]': 'B. Loyal Customers',
    r'[3-5][1-3][1-3]': 'C. Potential Loyalist',
    r'[4-5]11': 'D. New Customers',
    r'[3-4]11': 'E. Promising',
    r'[2-3][2-3][2-3]': 'F. Need Attention',
    r'[2-3][1-2][1-2]': 'G. About to Sleep',
    r'[1-2][2-5][2-5]': 'H. At Risk',
    r'1[4-5][4-5]': 'I. Can\'t Lose Them',
    r'[1-2][1-2][1-2]': 'J. Hibernating',
    r'55[1-2]': 'K. Outlier',
    r'11[4-5]': 'K. Outlier'
}

segt_other={r'[0-9]+':'L. Others'}

# %% [markdown]
# # Lógica de Clustering

# %%
data_all = pd.read_csv(fullpathdata,sep=",")
data_all.head(10)
# Out:
# D:\Anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (14,16,31,33,34,35,43,54,63,66,67,68,71,87,94,99,128,130,142,143,144,147,149,151,153) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    #Trips Out Of GeoFence %Utilization over Scooters Deployed  \
# 0                       0                                 66%
# 1                       0                                 55%
# 2                       0                                 55%
# 3                       0                                 55%
# 4                       0                                 69%
# 5                       0                                 68%
# 6                       0                                 68%
# 7                       0                                 68%
# 8                       0                                 58%
# 9                       0                                 58%
#
#    Cabify Avg. Duration (mins)  Blank 2  Blank 3  Blank 4  Cabify Fee  \
# 0                          4.3      NaN      NaN      NaN           0
# 1                          NaN      NaN      NaN      NaN           0
# 2                          NaN      NaN      NaN      NaN           0
# 3                          NaN      NaN      NaN      NaN           0
# 4                          NaN      NaN      NaN      NaN           0
# 5                          NaN      NaN      NaN      NaN           0
# 6                          NaN      NaN      NaN      NaN           0
# 7                          NaN      NaN      NaN      NaN           0
# 8                          NaN      NaN      NaN      NaN           0
# 9                          NaN      NaN      NaN      NaN           0
#
#    Cabify Avg. Ticket %Utilization over Total Fleet  New Users w/Discount  \
# 0                 1.0                       314200%                     0
# 1                 NaN                       258400%                     0
# 2                 NaN                       257300%                     0
# 3                 NaN                       257300%                     1
# 4                 NaN                       334800%                     0
# 5                 NaN                       323100%                     0
# 6                 NaN                       323100%                     0
# 7                 NaN                       344100%                     0
# 8                 NaN                       286300%                     0
# 9                 NaN                       286300%                     0
#
#    ...  trip_region  trips_order  type        updated_at    usd_xr  \
# 0  ...         Lima          5.0  kick   02/26/2020 8:44  0.294955
# 1  ...         Lima         11.0  kick  08/03/2020 20:36  0.294955
# 2  ...         Lima         10.0  kick  02/23/2020 17:11  0.294955
# 3  ...         Lima          1.0  kick  02/23/2020 21:04  0.294955
# 4  ...         Lima          1.0  kick  02/27/2020 13:05  0.294955
# 5  ...         Lima         22.0  kick  04/03/2020 21:07  0.294955
# 6  ...         Lima         21.0  kick  04/03/2020 19:44  0.294955
# 7  ...         Lima         34.0  kick  02/21/2020 12:37  0.294955
# 8  ...         Lima          1.0  kick  07/03/2020 20:54  0.294955
# 9  ...         Lima          2.0  kick  07/03/2020 22:30  0.294955
#
#   user_registration_date           vehicleid    zone_end  zone_final  \
# 0       08/26/2019 10:52  movo-scooter:18000  PER-LIM-E1  PER-LIM-E1
# 1       09/25/2019 21:15  movo-scooter:18889  PER-LIM-E1   PER-LIM-G
# 2       09/25/2019 21:15  movo-scooter:17978   PER-LIM-G   PER-LIM-G
# 3       02/23/2020 20:33  movo-scooter:14813  PER-LIM-E1  PER-LIM-E1
# 4       02/27/2020 10:16   movo-scooter:8673   PER-LIM-D   PER-LIM-B
# 5       09/21/2019 17:17   movo-scooter:8826   PER-LIM-E  PER-LIM-E1
# 6       09/21/2019 17:17   movo-scooter:8826  PER-LIM-E1  PER-LIM-E1
# 7       03/04/2019 20:28   movo-scooter:9682   PER-LIM-B   PER-LIM-B
# 8       02/21/2020 20:05   movo-scooter:9091   PER-LIM-E   PER-LIM-D
# 9       02/21/2020 20:05  movo-scooter:16020   PER-LIM-E   PER-LIM-E
#
#    zone_start
# 0  PER-LIM-E1
# 1   PER-LIM-G
# 2   PER-LIM-G
# 3  PER-LIM-E1
# 4   PER-LIM-B
# 5  PER-LIM-E1
# 6  PER-LIM-E1
# 7   PER-LIM-B
# 8   PER-LIM-D
# 9   PER-LIM-E
#
# [10 rows x 154 columns]

# %%
data_all.shape
# Out:
# (119718, 154)

# %%
data_all.columns
# Out:
# Index(['#Trips Out Of GeoFence', '%Utilization over Scooters Deployed',
#        'Cabify Avg. Duration (mins)', 'Blank 2', 'Blank 3', 'Blank 4',
#        'Cabify Fee', 'Cabify Avg. Ticket', '%Utilization over Total Fleet',
#        'New Users w/Discount',
#        ...
#        'trip_region', 'trips_order', 'type', 'updated_at', 'usd_xr',
#        'user_registration_date', 'vehicleid', 'zone_end', 'zone_final',
#        'zone_start'],
#       dtype='object', length=154)

# %% [markdown]
# # Filtramos las columnas necesarias para el cluster
# # UserId -> Identificador único del usuario
# # region_final -> Ciudad¶
# # #Trips -> Variable de trip
# # GMV - Rectifications -> GMV en dolares
# # Time -> Fecha de la transacción
# # Active Users -> Identificador si el usuario es activo con nuestro producto

# %%
columns_table = ["UserId", "region_final", "#Trips","GMV - Rectifications","Time","Active Users","type"]
row_filter = data_all["Active Users"]==1
data_reduce = data_all[row_filter][columns_table]
data_reduce.head(10)
# Out:
#          UserId region_final  #Trips  GMV - Rectifications        Time  \
# 0  2Hire:493113         Lima       1              1.032342  02/26/2020
# 1  2Hire:615547         Lima       1              1.032342  03/08/2020
# 2  2Hire:615547         Lima       1              0.736089  02/23/2020
# 3  2Hire:960601         Lima       1              4.128069  02/23/2020
# 4  2Hire:965978         Lima       1              9.291076  02/27/2020
# 5  2Hire:598047         Lima       1              2.800419  03/04/2020
# 6  2Hire:598047         Lima       1              1.621897  03/04/2020
# 7   2Hire:91227         Lima       1              0.589910  02/21/2020
# 8  2Hire:956039         Lima       1              2.507116  03/07/2020
# 9  2Hire:956039         Lima       1              1.917206  03/07/2020
#
#    Active Users  type
# 0             1  kick
# 1             1  kick
# 2             1  kick
# 3             1  kick
# 4             1  kick
# 5             1  kick
# 6             1  kick
# 7             1  kick
# 8             1  kick
# 9             1  kick

# %%
data_reduce["Fecha"] = data_reduce["Time"].apply(lambda x: format_date(x))
data_reduce.head(5)
# Out:
#          UserId region_final  #Trips  GMV - Rectifications        Time  \
# 0  2Hire:493113         Lima       1              1.032342  02/26/2020
# 1  2Hire:615547         Lima       1              1.032342  03/08/2020
# 2  2Hire:615547         Lima       1              0.736089  02/23/2020
# 3  2Hire:960601         Lima       1              4.128069  02/23/2020
# 4  2Hire:965978         Lima       1              9.291076  02/27/2020
#
#    Active Users  type       Fecha
# 0             1  kick  02/26/2020
# 1             1  kick  03/08/2020
# 2             1  kick  02/23/2020
# 3             1  kick  02/23/2020
# 4             1  kick  02/27/2020

# %%
data_reduce["Fecha_"] = data_reduce["Fecha"].apply(lambda x: datetime.strptime(x, "%m/%d/%Y"))
data_reduce.head(5)
# Out:
#          UserId region_final  #Trips  GMV - Rectifications        Time  \
# 0  2Hire:493113         Lima       1              1.032342  02/26/2020
# 1  2Hire:615547         Lima       1              1.032342  03/08/2020
# 2  2Hire:615547         Lima       1              0.736089  02/23/2020
# 3  2Hire:960601         Lima       1              4.128069  02/23/2020
# 4  2Hire:965978         Lima       1              9.291076  02/27/2020
#
#    Active Users  type       Fecha     Fecha_
# 0             1  kick  02/26/2020 2020-02-26
# 1             1  kick  03/08/2020 2020-03-08
# 2             1  kick  02/23/2020 2020-02-23
# 3             1  kick  02/23/2020 2020-02-23
# 4             1  kick  02/27/2020 2020-02-27

# %% [markdown]
# # Definirmos el RFM Table : Frequency,Monetary y Recency

# %%
rfm_table_global = data_reduce.groupby(['UserId','region_final',"type"]).agg({
        'Fecha_': lambda x: x.max(),
        '#Trips': 'count',
        'GMV - Rectifications': 'sum'}).reset_index()
rfm_table_global.rename(columns={ 'region_final':'Region',
                         'Fecha_':"Fecha",
                         '#Trips': 'Frequency',
                         'GMV - Rectifications': 'Monetary'}, inplace=True)
rfm_table_global["Recency"] = rfm_table_global["Fecha"].apply(lambda x: days_between(x,NOW))
rfm_table_global.head(10)
# Out:
#          UserId Region  type      Fecha  Frequency   Monetary  Recency
# 0  2Hire:100166   Lima  kick 2020-03-07         10   9.291076        2
# 1  2Hire:100243   Lima  kick 2020-03-02          8   7.227749        7
# 2  2Hire:100572   Lima  kick 2020-03-03          1   1.179819        6
# 3  2Hire:100690   Lima  kick 2020-02-23          1   3.095728       15
# 4  2Hire:100934   Lima  kick 2020-03-06         10  40.108130        3
# 5  2Hire:100943   Lima  kick 2020-03-03          2   2.064684        6
# 6  2Hire:101267   Lima  kick 2020-02-26          3   3.689295       12
# 7  2Hire:101453   Lima  kick 2020-02-21          2   3.686935       17
# 8  2Hire:101458   Lima  kick 2020-02-20          1   1.179819       18
# 9  2Hire:101498   Lima  kick 2020-03-05          1   0.884864        4

# %%
columns_table = ["Region", "type"]
data_type = rfm_table_global[columns_table]
data_type_asset = data_type.drop_duplicates(['Region','type']).reset_index()
data_type_asset.head(15)
# Out:
#    index Region  type
# 0      0   Lima  kick

# %%
rfm_table_global.describe()
# Out:
#           Frequency      Monetary       Recency
# count  17396.000000  17396.000000  17396.000000
# mean       3.044895      6.158587      8.044263
# std        4.011395      8.049756      5.184450
# min        1.000000     -0.003480      1.000000
# 25%        1.000000      1.622251      3.000000
# 50%        2.000000      3.098382      7.000000
# 75%        3.000000      7.078915     12.000000
# max       76.000000    147.320837     18.000000

# %%
k = int(np.ceil(1+np.log2(18000)))
plt.hist(rfm_table_global["Frequency"],bins= k, color="firebrick")
plt.xlabel("Frequency")
plt.ylabel("Frecuencia")
plt.title("Histograma de Frequency")
# Out:
# Text(0.5, 1.0, 'Histograma de Frequency')

# %%
plt.hist(rfm_table_global["Monetary"],bins= k, color="firebrick")
plt.xlabel("Monetary")
plt.ylabel("Frecuencia")
plt.title("Histograma de Monetary "  )
# Out:
# Text(0.5, 1.0, 'Histograma de Monetary ')

# %%
plt.hist(rfm_table_global["Recency"],bins= k, color="firebrick")
plt.xlabel("Recency")
plt.ylabel("Frecuencia")
plt.title("Histograma de Recency" )
# Out:
# Text(0.5, 1.0, 'Histograma de Recency')

# %% [markdown]
# # Definimos los quintiles de las variles Frequency,Monetary y Recency

# %%
quintiles_analysis = rfm_table_global[['Recency', 'Frequency', 'Monetary']].quantile([.2, .4, .6, .8]).to_dict()
quintiles_analysis_df = pd.DataFrame(quintiles_analysis)
quintiles_analysis_df.head(15)
# Out:
#      Recency  Frequency  Monetary
# 0.2      3.0        1.0  1.473476
# 0.4      5.0        1.0  2.503222
# 0.6      9.0        2.0  4.273954
# 0.8     13.0        4.0  8.848644

# %%
rfm_table_global = rfm_table_score(rfm_table_global,quintiles_analysis)
rfm_table_global.head(5)
# Out:
#          UserId Region  type      Fecha  Frequency   Monetary  Recency  R  F  \
# 0  2Hire:100166   Lima  kick 2020-03-07         10   9.291076        2  5  5
# 1  2Hire:100243   Lima  kick 2020-03-02          8   7.227749        7  3  5
# 2  2Hire:100572   Lima  kick 2020-03-03          1   1.179819        6  3  1
# 3  2Hire:100690   Lima  kick 2020-02-23          1   3.095728       15  1  1
# 4  2Hire:100934   Lima  kick 2020-03-06         10  40.108130        3  5  5
#
#    M RFM Score
# 0  5       555
# 1  4       354
# 2  1       311
# 3  3       113
# 4  5       555

# %%
rfm_table_global = rfm_table_segment(rfm_table_global,segt_map,segt_other)
rfm_table_global.head(5)
# Out:
#          UserId Region  type      Fecha  Frequency   Monetary  Recency  R  F  \
# 0  2Hire:100166   Lima  kick 2020-03-07         10   9.291076        2  5  5
# 1  2Hire:100243   Lima  kick 2020-03-02          8   7.227749        7  3  5
# 2  2Hire:100572   Lima  kick 2020-03-03          1   1.179819        6  3  1
# 3  2Hire:100690   Lima  kick 2020-02-23          1   3.095728       15  1  1
# 4  2Hire:100934   Lima  kick 2020-03-06         10  40.108130        3  5  5
#
#    M RFM Score                Segment
# 0  5       555           A. Champions
# 1  4       354     B. Loyal Customers
# 2  1       311  C. Potential Loyalist
# 3  3       113              L. Others
# 4  5       555           A. Champions

# %%
rfm_table_global.head(10)
# Out:
#          UserId Region  type      Fecha  Frequency   Monetary  Recency  R  F  \
# 0  2Hire:100166   Lima  kick 2020-03-07         10   9.291076        2  5  5
# 1  2Hire:100243   Lima  kick 2020-03-02          8   7.227749        7  3  5
# 2  2Hire:100572   Lima  kick 2020-03-03          1   1.179819        6  3  1
# 3  2Hire:100690   Lima  kick 2020-02-23          1   3.095728       15  1  1
# 4  2Hire:100934   Lima  kick 2020-03-06         10  40.108130        3  5  5
# 5  2Hire:100943   Lima  kick 2020-03-03          2   2.064684        6  3  3
# 6  2Hire:101267   Lima  kick 2020-02-26          3   3.689295       12  2  4
# 7  2Hire:101453   Lima  kick 2020-02-21          2   3.686935       17  1  3
# 8  2Hire:101458   Lima  kick 2020-02-20          1   1.179819       18  1  1
# 9  2Hire:101498   Lima  kick 2020-03-05          1   0.884864        4  4  1
#
#    M RFM Score                Segment
# 0  5       555           A. Champions
# 1  4       354     B. Loyal Customers
# 2  1       311  C. Potential Loyalist
# 3  3       113              L. Others
# 4  5       555           A. Champions
# 5  2       332  C. Potential Loyalist
# 6  3       243     B. Loyal Customers
# 7  3       133             H. At Risk
# 8  1       111         J. Hibernating
# 9  1       411  C. Potential Loyalist

# %%
rfm_table_global.to_csv(fullpathoutput+".csv")
